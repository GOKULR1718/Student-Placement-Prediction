# %%
#importing data from google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#importing required libraries
import numpy as np
import pandas as pd

# %%
#reading the dataset using pandas
df= pd.read_csv('/content/drive/MyDrive/ei_test_cgpa_trimmeduse - Copy.csv')

# %%
#1st 5 rows of the data set
df.head()
# Out:
#    Confidence  Anxiety  Self Esteem  Calmness  Self Control  Self Efficacy  \
# 0           5        4            5         6             4              6
# 1           4        4            4         5             5              5
# 2           4        4            4         4             4              3
# 3           5        4            5         5             5              4
# 4           3        3            3         4             4              6
#
#    Happiness  Emotional Intelligence  CGPA  ATTEMPT  \
# 0          5                       4  7.60        2
# 1          4                       4  7.35        2
# 2          4                       3  6.30        2
# 3          4                       4  8.50        2
# 4          3                       3  8.60        6
#
#    Satisfaction with placement  Placement   DV
# 0                            4          1  yes
# 1                            5          1  yes
# 2                            3          1  yes
# ...

# %%
df.drop(['DV'],axis=1,inplace=True)
df.head()
# Out:
#    Confidence  Anxiety  Self Esteem  Calmness  Self Control  Self Efficacy  \
# 0           5        4            5         6             4              6
# 1           4        4            4         5             5              5
# 2           4        4            4         4             4              3
# 3           5        4            5         5             5              4
# 4           3        3            3         4             4              6
#
#    Happiness  Emotional Intelligence  CGPA  ATTEMPT  \
# 0          5                       4  7.60        2
# 1          4                       4  7.35        2
# 2          4                       3  6.30        2
# 3          4                       4  8.50        2
# 4          3                       3  8.60        6
#
#    Satisfaction with placement  Placement
# 0                            4          1
# 1                            5          1
# 2                            3          1
# ...

# %%
x = df.iloc[:,0:8]

# %%
x.head()
# Out:
#    Confidence  Anxiety  Self Esteem  Calmness  Self Control  Self Efficacy  \
# 0           5        4            5         6             4              6
# 1           4        4            4         5             5              5
# 2           4        4            4         4             4              3
# 3           5        4            5         5             5              4
# 4           3        3            3         4             4              6
#
#    Happiness  Emotional Intelligence
# 0          5                       4
# 1          4                       4
# 2          4                       3
# 3          4                       4
# 4          3                       3

# %%
y = df[['Placement']]

# %%
y.head()
# Out:
#    Placement
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %%
#splitting the dataset into training and testing
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=99)

# %%
#importing randomforest classifier
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=100,criterion="gini",max_depth=10,min_samples_split=5,random_state=99)

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=10, min_samples_split=5, random_state=99)

# %%
x_new  = [[4,4,5,5,4,4,4,4]]
y_new = rf.predict(x_new)

# %%
y_new
# Out:
# array([1])
